# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\KELLSY\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import csv

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\KELLSY\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
data = pd.read_csv('Titanic.csv')
print(data)
# Out:
#                   PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Fare;Embarked
# 1;0;3;Braund                         Mr. Owen Harris;male;22;1;0;7;S
# 2;1;1;Cumings       Mrs. John Bradley (Florence Briggs Thayer);fe...
# 3;1;3;Heikkinen                        Miss. Laina;female;26;0;0;8;S
# 4;1;1;Futrelle      Mrs. Jacques Heath (Lily May Peel);female;35;...
# 5;0;3;Allen                        Mr. William Henry;male;35;0;0;8;S
# ...                                                              ...
# 887;0;2;Montvila                        Rev. Juozas;male;27;0;0;13;S
# 888;1;1;Graham               Miss. Margaret Edith;female;19;0;0;30;S
# 889;0;3;"Johnston   Miss. Catherine Helen ""Carrie""";female;0;1;...
# 890;1;1;Behr                        Mr. Karl Howell;male;26;0;0;30;C
# 891;0;3;Dooley                           Mr. Patrick;male;32;0;0;8;Q
#
# [891 rows x 1 columns]

# %%
data = pd.read_csv('Titanic.csv', sep=';', encoding='latin1', parse\_dates=['date'], dayfirst=True,)
print(df[:3])

# %%
data = pd.read_csv("Titanic.csv", index_col=0, parse_dates=True, )
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch  Fare Embarked
# 0      0     7        S
# 1      0    71        C
# 2      0     8        S
# 3      0    53        S
# 4      0     8        S

# %%
data = pd.read_csv("Titanic.csv", sep=';', encoding='latin1', parse_dates=True, )
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch  Fare Embarked
# 0      0     7        S
# 1      0    71        C
# 2      0     8        S
# 3      0    53        S
# 4      0     8        S

# %%
print (data['Name']) #filtramos solo por nombre
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Age'].plot()
plt.show()

# %%
data.plot(figsize=(15, 10))
plt.show()

# %%
data["Age"].plot()
data["Age"].rolling(window=20).mean().plot()
plt.show()

# %%
conda install -c anaconda sqlite
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
plt.style.use='default'
plt.rcParams['figure.figsize']=(15, 3)
plt.rcParams['font.family']='sans-serif'

# %%
weather_2012.csv
