# %% [markdown]
#  EJEMPLOS ESARROLLADOS

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt
from math import sqrt
from math import exp
import matplotlib.patches as patches

# %%
# X es variable de la cual va depender la funcion 
def funciones_mat(x):
    return np.sin(x)

# otra funcion g(x) coseno(x) 
g = lambda x: np.cos(x)

# vector
# x minimo y maximo 0 a 10
# y minimo y maximo -1 a 1
v=[0, 10, -1, 1]

# da una lista de valores que puede tomar X
# cantidad de puntos a graficar (de 0 a 10, 100 puntos)
x=np.linspace(0,10,100)

# graficamos 
# variables, funcion, tipo de linea , texto
plt.plot(x,funciones_mat(x), 'g-', label='seno')

# funcion g
plt.plot(x,g(x), label='coseno')

# nombre de eje x      simbolo latex, alpha
plt.xlabel('tiempo' r'$\tau$')

# nombre eje y
plt.ylabel('posicion' r'$\alpha$')

# titulo de grafica
plt.title('Funcion seno')

# leyenda
plt.legend(loc=3)

# agregar texto en la grafica
# 4 en eje x y 0 en eje y
plt.text(4,0,'prueba')
plt.axis(v)

# cuadricula
plt.grid()

# guardar grafica
plt.savefig('seno_coseno.png')

# %%
# definimos las funciones 
# foma corta de definir funciones paqueñas
g = lambda x: np.cos(x)+2
h = lambda x: np.exp(x)
f = lambda x: np.sin(x)+1

# Lista de valores que toma x
# significa inicio, fin, cant de saltos o pasos
x=np.arange(0,10,0.1)

# graficamos g(x)
# columna
# 2 filas, 2 columnas, posicion 1
plt.subplot(2,2,1)
plt.plot(x,g(x), label='coseno')
plt.ylabel('Año' r'$\alpha$')
plt.xlabel('Meses' r'$\alpha$')
#plt.show()

plt.subplot(2,2,2)
plt.plot(x,h(x), label='Exponente')
plt.ylabel('Año' r'$\alpha$')
plt.xlabel('Meses' r'$\alpha$')
#plt.show()

# graficamos la funcion f(x)
plt.subplot(2,2,3)
plt.plot(x,f(x), label='Seno')
plt.ylabel('Año' r'$\alpha$')
plt.xlabel('Meses' r'$\alpha$')
#plt.show()
# Out:
# Text(0.5, 0, 'Meses$\\alpha$')

# %% [markdown]
# ## Ejercicios MatPlotLib

# %% [markdown]
# **1. Realice una grafica de la funcion coseno para 100 valores de angulo entre [-pi, pi].
# Muestrelo por pantalla.**

# %%
m = lambda r: np.cos(r)
# con el arange no funciona
r=np.linspace(-np.pi,np.pi,100)

plt.plot(r,m(r), label='Seno')
plt.title('Funcion seno')
plt.ylabel('Eje Y')
plt.xlabel('Eje x')
#plt.text(0,1,'Funcion seno', rotation=45)

plt.show()

# %% [markdown]
# **2. Grafique la funcion y = x 2 + 2 para 50 valores de x en [-1, 1]. Almacene la grafica en
# un fichero de nombre parabola.png’.**

# %%
def f(y):
    return x**2 + 2

# toma valores enteros
y = np.linspace(-1,1,50)

plt.plot(y,f(y))
plt.title('Funcion de Y')
plt.ylabel('Eje Y')
plt.xlabel('Eje x')
plt.savefig('Funcion_Y.png') # guardar grafica
# cuadricula
plt.grid()
plt.show()
print(y)
# Out:
# [-1.         -0.95918367 -0.91836735 -0.87755102 -0.83673469 -0.79591837
#  -0.75510204 -0.71428571 -0.67346939 -0.63265306 -0.59183673 -0.55102041
#  -0.51020408 -0.46938776 -0.42857143 -0.3877551  -0.34693878 -0.30612245
#  -0.26530612 -0.2244898  -0.18367347 -0.14285714 -0.10204082 -0.06122449
#  -0.02040816  0.02040816  0.06122449  0.10204082  0.14285714  0.18367347
#   0.2244898   0.26530612  0.30612245  0.34693878  0.3877551   0.42857143
#   0.46938776  0.51020408  0.55102041  0.59183673  0.63265306  0.67346939
#   0.71428571  0.75510204  0.79591837  0.83673469  0.87755102  0.91836735
#   0.95918367  1.        ]

# %%
def funcion_y(y):
    return x**2 + 2
# toma valores enteros
y = np.linspace(-1,1,50)

# A rannge toma numeros decimales
#x = np.arange(-1,1,50)
#y = mt.exp(x)**2 + 2
#y = mt.exp(x)**2 + 2
#y = mt.pow(x,2)+2


plt.plot(y,funcion_y(y))
plt.title('Funcion de Y')
plt.ylabel('Eje Y')
plt.xlabel('Eje x')

print(y)
# Out:
# [-1.         -0.95918367 -0.91836735 -0.87755102 -0.83673469 -0.79591837
#  -0.75510204 -0.71428571 -0.67346939 -0.63265306 -0.59183673 -0.55102041
#  -0.51020408 -0.46938776 -0.42857143 -0.3877551  -0.34693878 -0.30612245
#  -0.26530612 -0.2244898  -0.18367347 -0.14285714 -0.10204082 -0.06122449
#  -0.02040816  0.02040816  0.06122449  0.10204082  0.14285714  0.18367347
#   0.2244898   0.26530612  0.30612245  0.34693878  0.3877551   0.42857143
#   0.46938776  0.51020408  0.55102041  0.59183673  0.63265306  0.67346939
#   0.71428571  0.75510204  0.79591837  0.83673469  0.87755102  0.91836735
#   0.95918367  1.        ]

# %% [markdown]
# **3. Dibuje la funci´on exponencial frente a la identidad (x = y) en [-1, 1] para 30 puntos.
# La exponencial ser´a representada por puntos verdes. La identidad, por una l´ınea roja.
# Guarde el gr´afico con el nombre ’dosFunciones.png’**

# %%
def funcion_exp(y):
    return x == y
g = lambda x: np.exp(x)
y = np.linspace(-1,1,30)

plt.plot(y,funcion_exp(y),'g.')
plt.plot(x,g(x), 'r-')
plt.title('Funcion de Y')
plt.ylabel('Eje Y')
plt.xlabel('Eje x')
print(y)
# Out:
# [-1.         -0.93103448 -0.86206897 -0.79310345 -0.72413793 -0.65517241
#  -0.5862069  -0.51724138 -0.44827586 -0.37931034 -0.31034483 -0.24137931
#  -0.17241379 -0.10344828 -0.03448276  0.03448276  0.10344828  0.17241379
#   0.24137931  0.31034483  0.37931034  0.44827586  0.51724138  0.5862069
#   0.65517241  0.72413793  0.79310345  0.86206897  0.93103448  1.        ]

# %% [markdown]
# **4. Cree una grafica en la que genere un rectangulo de vertices (1,2), (4,2), (1,1) y (4,1) mediante 2 lineas horizontales y 2 verticales. Muestre cada lınea de un color**

# %%
import turtle
  
t = turtle.Turtle()
 
s = int(input("Enter the length of the side of the Squre: "))
 
t.forward(s) 
t.left(90) 
 
t.forward(s) 
t.left(90) 
 
t.forward(s) 
t.left(90) 
 
t.forward(s) 
t.left(90)

# %%
out_mat = geek.matlib.identity(x=y)
out_mat

# %%
vertices = [1,2, 4,2 ,1,1 ,4,1]
plt.plot(vertices)

# %%
# 4. Cree una grafica en la que genere un rectangulo de
# vertices (1,2), (4,2), (1,1) y (4,1) 
# mediante 2 lineas horizontales y 2 verticales. 
#Muestre cada lınea de un color
fig, ax = plt.subplots()
ax.plot(y)
rect = Rectangle((4, 2), 1, 2,
                alpha = 0.2,
                facecolor = "SaddleBrown",
                edgecolor = "red",
                linewidth = 2)
ax.add_patch(rect)
plt.show()

# %%
patches.Rectangle(
        (1, 1),
        1,
        2,
        edgecolor = 'blue',
        facecolor = 'red',
        fill=True
 )
plt.show()

# %%
# Dibujando manualmente una circunferencia
# Aprovechamos que el módulo numpy nos brinda pi, cos() y sin()
import matplotlib.pyplot as plt
import numpy as np

num_puntos = 1000
titas = np.linspace(0, 2*np.pi, num_puntos)  # num_puntos valores equidistantes en el intervalo [0,2*pi]

centro = (350, 250)
radio = 75.3

# Creamos las listas de coordenadas
lista_x = [0]*num_puntos
lista_y = [0]*num_puntos
for i, tita in enumerate(titas):  # Generamos los num_puntos de la circunferencia
    lista_x[i] = centro[0] + radio*np.cos(tita)
    lista_y[i] = centro[1] + radio*np.sin(tita)

plt.scatter(lista_x, lista_y, s=0.1)
plt.title('Circunferencia de centro {} y radio {}'.format(centro, radio))
plt.axis('scaled')
# Out:
# (267.1703909513261, 432.8299813832702, 167.1701023920773, 332.8298976079227)

# %%
# Dibujando manualmente un segmento de recta
import matplotlib.pyplot as plt
import numpy as np

def genera_coordenadas_segmento(p1, p2, num_puntos):
    
    lambdas = np.linspace(0, 1, num_puntos)  # num_puntos valores equidistantes en el intervalo [0,1]

    v_x, v_y = (p2[0]-p1[0], p2[1]-p1[1])  # (vx, vy) Vector director

    # Creamos las listas de coordenadas
    lista_x = [0]*num_puntos
    lista_y = [0]*num_puntos
    for i, l in enumerate(lambdas):
        lista_x[i] = p1[0] + l*v_x
        lista_y[i] = p1[1] + l*v_y
        
    return lista_x, lista_y

        
num_puntos = 1000
p1 = (100, 50)
p2 = (-150, 300)

lista_x, lista_y = genera_coordenadas_segmento(p1, p2, num_puntos)

plt.scatter(lista_x, lista_y, s=0.1)
plt.title('Segmento de recta entre los puntos {} y {}'.format(p1, p2))
plt.axis('scaled')
# Out:
# (-162.5, 112.5, 37.5, 312.5)

# %% [markdown]
# * EJEMPLO

# %%
lenguajes = ('python', 'Java', 'Php', 'Go', 'JavaScript')
cantidad = ('200', '180', '190','120','100')
colores = ('red','#DD98AA','blue','green','orange')
valores = (0.1,0,0,0,0)

plt.rcParams['toolbar'] = 'None'
_, _, texto = plt.pie(cantidad, colors=colores, labels=lenguajes, autopct='%1.1f%%', explode = valores, startangle=90)

for tex in texto:
    tex.set_color('white')

plt.axis('equal')
plt.title('Grafica de lenguajes de programacion')
plt.show()

#plt.savefig('Lenguajes.png')
